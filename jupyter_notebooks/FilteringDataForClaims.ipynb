# %% [markdown]
# ## Filter DataFrames for Claims by URL
# This notebook consists of several methods and helper methods that will filter dataframes of any size. Filtering process includes sorting out non-english tweets, tweets that don't reference a URL, and tweets that aren't associated with a place. There are also methods to identify key topics from a tweet based off of defined keywords related to cures and prevention methods for COVID-19. Finally, once a dataframe is filtered, the top URLs from a dataframe can be identified along with the specific tweet that referenced that URL.
#
# This script is meant to be run from start to finish. If you run the main function and realize you need to change a functionality in one of the methods, you will have to rerun the processing data files function.

# %%
import pandas as pd
from pathlib import Path
from langdetect import detect, lang_detect_exception, DetectorFactory
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import defaultdict
from nltk.corpus import wordnet as wn

# %% [markdown]
# ### Processing data files into DataFrames
# If you have several JSON files in a folder, run lines 5 and 6 below and comment out line 2 and 3. You should change the path to match where you have your data files located. If you have data files in another format other than JSON, change line 6 to match your file type.

# %%
#data path to folder with JSON files
data_dir = Path('../..') / 'data_samples/json_files/may_sample'
data_files = data_dir.glob('*.json')

# %% [markdown]
# ### Methods to Filter DataFrames
# detectLang method was inspired by Pysmap library (source: https://github.com/SMAPPNYU/pysmap#detect_tweet_language)
#
# lemmatization method was used from https://medium.com/@bedigunjit/simple-guide-to-text-classification-nlp-using-svm-and-naive-bayes-with-python-421db3a72d34

# %%
#Determine language by langDetect 
def detectLang(tweet):
    DetectorFactory.seed = 0
    detected_lang = None
    try: 
        detected_lang = detect(tweet['full_text'])             
    except:
        pass

    return detected_lang

# %%
#Filter out if a tweet is associated with a location
def hasPlace(tweet):
    if tweet['place'] == None:
        return False
    else: 
        return True

# %%
#Filter out if a tweet is associated with a url
def hasURL(tweet):
    if len(tweet['entities']['urls']) == 0:
        return False
    else: 
        return True

# %%
#Helper method to modify columns; scrape fields from a tweet to generate a quick link to be clicked to view the tweet object on twitter
def tweetOnTwitter(df):
    for i in range(len(df)):  
        begin = 'https://twitter.com/'
        username = df.loc[i]['user']['screen_name']
        breakin = '/'
        status = 'status' 
        tweetid = str(df.loc[i]['id'])
        urlstr = begin+username+breakin+status+breakin+tweetid
        df.at[i, 'tweet_on_twitter'] = urlstr
    
    return df

# %%
#Add two columns in the first half of the dataframe to easily view the link referenced in the tweet and the 
#tweet direct link to view on twitter
def modifyColumns(df):
    #Create a quick an easy URL Link column to view the link that is being referenced.
    try:
        df.insert(3, 'url_link', '')
    except:
        pass
    
    for i in range(len(df)):
        if len(df.loc[i]['entities']['urls']) > 0:
            urlstr = df.loc[i]['entities']['urls'][0]['expanded_url']
            df.at[i, 'URL_link'] = urlstr
    #create a quick and easy column to view the tweet on twitter
    try:
        df.insert(4, 'tweet_on_twitter','')
    except:
        pass
    return tweetOnTwitter(df)

# %%
#Filters the dataframe by getting rid of tweets that don't reference a URL, don't have a place, and is only in english
def filterDF(df):
    dropList = []
    for i in range(len(df)):
        #fix the language
        df.at[i, 'lang'] = detectLang(df.loc[i])

        #drop records that don't have a url or a place
        if not hasPlace(df.loc[i]):
            dropList.append(i)
        if not hasURL(df.loc[i]):
            if not i in dropList:
                dropList.append(i)

    #at the end remove all the records from the droplist
    df = df.drop(dropList, axis=0)
    df = df[df['lang'] == 'en']
    df = df.reset_index()
    return df

# %%
def lemmatization(df):
    #Twitter specific stopwords
    tweetWords = ['rt', 'co', 'https']
    #Change all the text to lower case
    df['full_text'] = [entry.lower() for entry in df['full_text']]
    #Tokenize each entry
    tokens = [word_tokenize(entry) for entry in df['full_text']]
    #Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
    #WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
    tag_map = defaultdict(lambda : wn.NOUN)
    tag_map['J'] = wn.ADJ
    tag_map['V'] = wn.VERB
    tag_map['R'] = wn.ADV
    for index,entry in enumerate(tokens):
        #Declaring Empty List to store the words that follow the rules for this step
        Final_words = []
        #Initializing WordNetLemmatizer()
        word_Lemmatized = WordNetLemmatizer()
        #pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
        for word, tag in pos_tag(entry):
            #Below condition is to check for Stop words and consider only alphabets
            if word not in stopwords.words('english') and word not in tweetWords and word.isalpha():
                word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
                Final_words.append(word_Final)
        #The final processed set of words for each iteration will be stored in 'text_final'
        df.loc[index,'text_final'] = str(Final_words)
        
    return df

# %%
def topics(df):
    #keywords relating to COVID-19 cures, preventions, spread, and origin
    keywords = ['cure', 'oil', 'remedy', 'medicine', 'tradition','traditional', 'natural', 'tea', 'whiskey', 'honey', 'mask', 'n95',
               'garlic', 'oregano','sesame','prevent','help', 'pee', 'poop', 'dung', 'cow', 'rare', 'drink', 'drugs',
               'urine', 'anti-HIV', 'HIV', 'drug', 'wear', 'try', 'eat', 'use', 'health', 'origin', 'bioweapon', 'canada',
               'spread', 'snake', 'bat', 'market', 'wuhan']
    df['topics'] = None #Created a topics column in the dataframe to identify tweets matching with keywords/topics
    for i in range(len(df)):
        topicWords = []
        text_final = df.loc[i]['text_final']
        for word in keywords:
            if word in text_final:
                topicWords.append(word)
        df.at[i, 'topics'] = topicWords
    
    return df

# %%
def topURLs(df):
    #create lang dictionary to get a count of the number of times a url is tweeted
    tweet_URLs = {}
    url_to_tweet_map = {}

    for i in range(len(df)):
        if hasURL(df.loc[i]):
            expURL = df.loc[i]['entities']['urls'][0]['expanded_url']
            if expURL.startswith('https://twitter.com/'):
                continue
            else: 
                if expURL in tweet_URLs:
                    tweet_URLs[expURL] += 1
                else:
                    tweet_URLs[expURL] = 1

                if expURL in url_to_tweet_map:
                    url_to_tweet_map[expURL].append(i)
                else:
                    url_to_tweet_map[expURL] = []
                    url_to_tweet_map[expURL].append(i)
        else:
            continue;
            
    return tweet_URLs, url_to_tweet_map

# %% [markdown]
# ### Main function
# If you have multiple data files in one folder uncomment the code in the cell directly below and comment the code in the following cell make sure to change numb_files to the number of files you have. This is used for a print statement to let you know the progress of the filtering. Also change the name of what the dataframe is going to be saved as and the file type.

# %%
#For Multiple Files in a directory
result_dfs = []
numb_files = 3
file_count = 0.0
count = 0
for file in data_files:
    df = pd.read_json(str(file), lines=True)
    df = modifyColumns(df)
    result_dfs.append(df)
    file_count += 1
    completed = file_count / numb_files
    print("Completed: {:.2%}".format(completed))
    
final_df = pd.concat(result_dfs)
final_df = final_df.reset_index()
data_dir = Path('../..') / 'data_samples/'
final_df.to_csv(str(data_dir) + '/file_filtered.csv')
final_df.head(1)
# Out:
# Completed: 33.33%
# Completed: 66.67%
# Completed: 100.00%
#    index                created_at                   id               id_str  \
# 0      0 2020-05-01 02:04:02+00:00  1256041661152612352  1256041661152612352
#
#   url_link                                   tweet_on_twitter  \
# 0           https://twitter.com/PlSmith57/status/125604166...
#
#                                            full_text  truncated  \
# 0  Received this email. Apparently there is a “Na...      False
#
#   display_text_range                                           entities  ...  \
# 0           [0, 216]  {'hashtags': [], 'symbols': [], 'user_mentions...  ...
#
#   favorited retweeted  possibly_sensitive  lang  quoted_status_id  \
# 0     False     False                 0.0    en               NaN
#
#    quoted_status_id_str quoted_status_permalink quoted_status  \
# 0                   NaN                     NaN           NaN
#
#    retweeted_status  URL_link
# 0               NaN       NaN
#
# [1 rows x 35 columns]

# %%
tweet_urls, urls_to_tweet_map = topURLs(final_df)

# %%
tweet_urls
# Out:
# {'https://urmedium.com/c/presstv/14102?utm_source=dlvr.it&utm_medium=twitter': 1,
#  'http://www.lanacion.com.ar/2360167': 1,
#  'http://chronlaw.com/texas-still-wont-say-which-nursing-homes-have-covid-19-cases-families-are-demanding-answers/': 1,
#  'https://on.ft.com/2VQeabd': 1,
#  'https://www.sports-tokyo-info.metro.tokyo.lg.jp/stayhome_enjoysports.html': 1,
#  'http://dlvr.it/RVnkRc': 1,
#  'https://www.entregrillosychapulines.com/wp-content/uploads/2020/04/osorio-chong.jpg': 1,
#  'http://www.safetyhealthnews.com/as-covid-19-shutters-practices-virtual-doc-patient-activity-soars/': 1,
#  'https://mile.io/3d4TVMF': 1,
#  'https://trib.al/rHC1Ous': 1,
#  'https://www.elindependiente.com/politica/2020/04/30/plasticos-en-los-juzgados-para-protegerse-del-coronavirus-no-hay-presupuesto/': 1,
#  'https://www.suara.com/lifestyle/2020/05/01/085855/pria-india-pamit-pergi-belanja-saat-lockdown-pulang-malah-bawa-pengantin?utm_source=twitter.dlvrit&utm_medium=twitter&utm_campaign=suaradotcom': 1,
#  'http://dld.bz/jc8Qh': 1,
#  'https://abcn.ws/35i1k8N': 1,
#  'https://tokyodouga.jp/fqfdwtotar0.html': 1,
#  'https://www.wbaltv.com/article/national-coronavirus-updates-april-30/32327859': 1,
#  'http://www.donantecovid.cl': 1,
#  'http://RCCD.edu/covid_funding_resources': 1,
#  'http://dlvr.it/RVnkRq': 1,
#  'http://dlvr.it/RVnkRz': 1,
#  'http://www.univarta.com/the-number-of-corona': 1,
#  'http://dlvr.it/RVnkSB': 1,
#  'https://www.cnn.com/2020/04/30/business/lessons-from-china-business-coronavirus-intl-hnk/index.html': 1,
#  'https://veja.abril.com.br/brasil/o-coronavirus-chega-a-favela/': 1,
#  'https://www.vice.com/en_us/article/xgqe7n/couples-fighting-over-habits-during-coronavirus-pandemic-shelter-in-place': 1,
#  'http://ctxt.es/es/20200401/Firmas/32052/Gerardo-Pisarello-republicas-abril-coronavirus-pandemia-antifascismo.htm#.XqtpROGWgBc.twitter': 1,
#  'https://apnews.com/490aee062b36ab64c76c624f9674a89c': 1,
#  'https://bit.ly/3bTINlI': 1,
#  'https://buff.ly/2VTaiGv': 1,
#  'https://www.soumu.go.jp/menu_seisaku/gyoumukanri_sonota/covid-19/kyufukin.html': 2,
#  'https://www.pscp.tv/w/cXoMAjFNV0V3YUdBTFhrS2J8MURYR3llZUx5V1dHTUIapkXIkBQV3yQbZkwd1gnxHRbO4j0fskYMqBaPJfH-': 1,
#  'https://bit.ly/3d0UMxR': 1,
#  'https://www.zerohedge.com/geopolitical/trump-wants-us-troops-immediately-out-afghanistan-due-coronavirus': 1,
#  'https://paper.li/e-1497917245?edition_id=5b66e820-8b40-11ea-8c96-0cc47a0d1605': 1,
#  'https://bit.ly/3aRlU0V': 1,
#  'https://techcrunch.com/2020/04/20/can-employers-mandate-covid-19-testing/': 1,
#  'http://www.borderlandbeat.com/2020/04/wuhan-was-fentanyl-capital-then.html': 1,
#  'https://bit.ly/2KRJz6A': 1,
#  'http://dlvr.it/RVnCp0': 1,
#  'https://thehardtimes.net/culture/sesame-street-airs-special-episode-to-explain-coronavirus-to-the-president/': 1,
#  'https://www.google.com/amp/s/www.vanityfair.com/news/2020/04/donald-trump-coronavirus-meltdown/amp': 1,
#  'https://inspirationbylorettaexclusive.com/products/womens-im-more-cropped-t-shirt': 1,
#  'https://petitions.whitehouse.gov/petition/dear-mr-president-trump-please-immediately-remove-occupying-body-federal-republic-germany-frg': 1,
#  'https://nypost.com/2020/04/30/artists-use-coronavirus-crisis-to-make-masks-from-used-panties/': 1,
#  'https://www.esitv.com/news/index.php/nacionales/2630-asamblea-supera-veto-presidencial-a-ley-para-proteger-los-derechos-durante-emergencia-del-covid-19': 1,
#  'https://www.huffpost.com/entry/michigan-court-rules-stay-home-stay-safe-order-doesnt-infringe-on-rights_n_5eab0fd8c5b633a854471ded?ncid=engmodushpmg00000004': 1,
#  'https://www.pscp.tv/w/cXoMTDFYSlFrdkp2QXlZRUx8MWRSS1pRUXJua3J4Qpvnd8XtHiSXGFXSjuuuI06-CxzdKW_LRzqy3wqUlxLR': 1,
#  'https://www.washingtonpost.com/opinions/2020/04/30/india-is-using-pandemic-intensify-its-crackdown-kashmir/': 1,
#  'https://noticias.uol.com.br/ao-vivo/2020/03/18/coronavirus-pelo-mundo.htm?c=card_2066702646_1588283318000': 1,
#  'https://www.abcactionnews.com/rebound/coronavirus-money-help/florida-housing-market-takes-major-hit-from-coronavirus-rebound-timeframe-uncertain?fbclid=IwAR0TxNzRSywLpecCZ0houqfAcGwGFE3N6XDmXn7dU8D-ByN6n_zEdh-wkFM': 1,
#  'https://lasillarota.com/estados/nace-otro-bebe-milagro-en-monclova-monclova-bebe-milagro-dia-del-nino-madre-covid/386696': 1,
#  'https://amazon.com/PHANTOM-APOCALYPSE-Dystopian-Jon-Kofas-ebook/dp/B07SLZLC4Q/ref=sr_1_1?keywords=jon+kofas&qid=1563635435&s=gateway&sr=8-1': 1,
#  'https://bit.ly/2y8ciBx': 1,
#  'https://bit.ly/3bUVeO1': 1,
#  'http://www.gob.cl/coronavirus': 1,
#  'http://abcn.ws/2RiH3wd': 1,
#  'http://mill.yt/g3vh4': 1,
#  'https://dailyaaj.com.pk/news/31545': 1,
#  'https://wdrb.news/2KSCnal': 1,
#  'https://www.prosoundnetwork.com/pro-sound-news-blog/pandemic-production-whatever-it-takes': 1,
#  'https://bit.ly/GimnasiosOnline': 1,
#  'https://cbsn.ws/2Wgbvqa': 1,
#  'https://oklahoman.com/article/5661243/coronavirus-stimulus-six-reasons-your-1200-check-may-not-be-in-the-mail': 1,
#  'https://www.gsnoticias.com/recaudo-de-impuestos-en-monteria-ha-caido-en-un-30-por-la-covid-19/': 1,
#  'https://www.comicsands.com/ben-shapiro-elderly-deaths-pandemic-2645883827.html': 1,
#  'https://bit.ly/3ajbWpB': 1,
#  'http://spr.ly/60181fxwi': 1,
#  'https://tkpo.st/2xhyHMe': 1,
#  'https://bit.ly/2YkynHC': 1,
#  'https://247sports.com/college/arkansas/Article/Commissioner-Greg-Sankey-provides-update-on-SEC-Media-Days-July-13-16-Atlanta-COVID-19-coronavirus-pandemic-146634189/': 1,
#  'https://www.instagram.com/p/B_oEJnNnp3L/?igshid=1f0ro9q2skdhi': 1,
#  'https://bit.ly/2YmToBO': 1,
#  'https://jurnaltr.com/elon-musk-koronavirus-onlemlerini-fasistlik-diye-niteledi/': 1,
#  'https://gyao.yahoo.co.jp/special/gw2020/?source=external.twitter': 1,
#  'https://cnycentral.com/news/local/lawyers-anticipate-covid-19-will-change-the-approach-to-living-wills': 1,
#  'http://bit.ly/2z1fqPz': 1,
#  'https://bit.ly/2VT7GIH': 1,
#  'https://www.em.com.br/app/noticia/politica/2020/04/30/interna_politica,1143431/coronavirus-damares-usa-mascara-de-mulher-maravilha-em-apelo-por-cria.shtml': 1,
#  'https://cet.informabi.com/three-more-chick-fil-employees-test-positive-covid-19': 1,
#  'https://i.inewsgr.com/m8ogj': 1,
#  'https://www.aoitori.be/news/belgium/corona-3-may.html': 1,
#  'https://www.aberdeennews.com/ap/national/minnesota-nursing-home-reports-47-deaths-from-coronavirus/article_b4671568-3311-5e79-9bc3-c4bcfd78d109.html?utm_medium=social&utm_source=twitter_AberdeenNews': 1,
#  'https://buff.ly/2y7GcWK': 1,
#  'https://covid19-japan.com/latest': 1,
#  'http://www.tdb.org.tr/icerik_goster.php?Id=3467': 1,
#  'https://www.nytimes.com/2020/04/30/health/coronavirus-antiviral-drugs.html': 1,
#  'https://bit.ly/35mlnTE': 1,
#  'https://www.wlns.com/news/health/coronavirus/sparrow-refocuses-donation-efforts-after-collecting-more-than-270000-items-from-community/?utm_medium=social&utm_source=twitter_WLNS': 1,
#  'https://reut.rs/35iqNir': 1,
#  'https://medium.com/conversations-with-tyler/glen-weyl-tyler-cowen-covid-19-coronavirus-pandemic-relief-e4869e1a7a51': 1}

# %%
urls_to_tweet_map
# Out:
# {'https://urmedium.com/c/presstv/14102?utm_source=dlvr.it&utm_medium=twitter': [6],
#  'http://www.lanacion.com.ar/2360167': [12],
#  'http://chronlaw.com/texas-still-wont-say-which-nursing-homes-have-covid-19-cases-families-are-demanding-answers/': [22],
#  'https://on.ft.com/2VQeabd': [30],
#  'https://www.sports-tokyo-info.metro.tokyo.lg.jp/stayhome_enjoysports.html': [41],
#  'http://dlvr.it/RVnkRc': [42],
#  'https://www.entregrillosychapulines.com/wp-content/uploads/2020/04/osorio-chong.jpg': [43],
#  'http://www.safetyhealthnews.com/as-covid-19-shutters-practices-virtual-doc-patient-activity-soars/': [45],
#  'https://mile.io/3d4TVMF': [49],
#  'https://trib.al/rHC1Ous': [54],
#  'https://www.elindependiente.com/politica/2020/04/30/plasticos-en-los-juzgados-para-protegerse-del-coronavirus-no-hay-presupuesto/': [55],
#  'https://www.suara.com/lifestyle/2020/05/01/085855/pria-india-pamit-pergi-belanja-saat-lockdown-pulang-malah-bawa-pengantin?utm_source=twitter.dlvrit&utm_medium=twitter&utm_campaign=suaradotcom': [60],
#  'http://dld.bz/jc8Qh': [65],
#  'https://abcn.ws/35i1k8N': [66],
#  'https://tokyodouga.jp/fqfdwtotar0.html': [70],
#  'https://www.wbaltv.com/article/national-coronavirus-updates-april-30/32327859': [74],
#  'http://www.donantecovid.cl': [76],
#  'http://RCCD.edu/covid_funding_resources': [78],
#  'http://dlvr.it/RVnkRq': [81],
#  'http://dlvr.it/RVnkRz': [82],
#  'http://www.univarta.com/the-number-of-corona': [85],
#  'http://dlvr.it/RVnkSB': [89],
#  'https://www.cnn.com/2020/04/30/business/lessons-from-china-business-coronavirus-intl-hnk/index.html': [99],
#  'https://veja.abril.com.br/brasil/o-coronavirus-chega-a-favela/': [102],
#  'https://www.vice.com/en_us/article/xgqe7n/couples-fighting-over-habits-during-coronavirus-pandemic-shelter-in-place': [108],
#  'http://ctxt.es/es/20200401/Firmas/32052/Gerardo-Pisarello-republicas-abril-coronavirus-pandemia-antifascismo.htm#.XqtpROGWgBc.twitter': [111],
#  'https://apnews.com/490aee062b36ab64c76c624f9674a89c': [116],
#  'https://bit.ly/3bTINlI': [118],
#  'https://buff.ly/2VTaiGv': [119],
#  'https://www.soumu.go.jp/menu_seisaku/gyoumukanri_sonota/covid-19/kyufukin.html': [123,
#   126],
#  'https://www.pscp.tv/w/cXoMAjFNV0V3YUdBTFhrS2J8MURYR3llZUx5V1dHTUIapkXIkBQV3yQbZkwd1gnxHRbO4j0fskYMqBaPJfH-': [129],
#  'https://bit.ly/3d0UMxR': [132],
#  'https://www.zerohedge.com/geopolitical/trump-wants-us-troops-immediately-out-afghanistan-due-coronavirus': [135],
#  'https://paper.li/e-1497917245?edition_id=5b66e820-8b40-11ea-8c96-0cc47a0d1605': [138],
#  'https://bit.ly/3aRlU0V': [140],
#  'https://techcrunch.com/2020/04/20/can-employers-mandate-covid-19-testing/': [144],
#  'http://www.borderlandbeat.com/2020/04/wuhan-was-fentanyl-capital-then.html': [146],
#  'https://bit.ly/2KRJz6A': [157],
#  'http://dlvr.it/RVnCp0': [162],
#  'https://thehardtimes.net/culture/sesame-street-airs-special-episode-to-explain-coronavirus-to-the-president/': [166],
#  'https://www.google.com/amp/s/www.vanityfair.com/news/2020/04/donald-trump-coronavirus-meltdown/amp': [171],
#  'https://inspirationbylorettaexclusive.com/products/womens-im-more-cropped-t-shirt': [180],
#  'https://petitions.whitehouse.gov/petition/dear-mr-president-trump-please-immediately-remove-occupying-body-federal-republic-germany-frg': [186],
#  'https://nypost.com/2020/04/30/artists-use-coronavirus-crisis-to-make-masks-from-used-panties/': [188],
#  'https://www.esitv.com/news/index.php/nacionales/2630-asamblea-supera-veto-presidencial-a-ley-para-proteger-los-derechos-durante-emergencia-del-covid-19': [190],
#  'https://www.huffpost.com/entry/michigan-court-rules-stay-home-stay-safe-order-doesnt-infringe-on-rights_n_5eab0fd8c5b633a854471ded?ncid=engmodushpmg00000004': [197],
#  'https://www.pscp.tv/w/cXoMTDFYSlFrdkp2QXlZRUx8MWRSS1pRUXJua3J4Qpvnd8XtHiSXGFXSjuuuI06-CxzdKW_LRzqy3wqUlxLR': [205],
#  'https://www.washingtonpost.com/opinions/2020/04/30/india-is-using-pandemic-intensify-its-crackdown-kashmir/': [209],
#  'https://noticias.uol.com.br/ao-vivo/2020/03/18/coronavirus-pelo-mundo.htm?c=card_2066702646_1588283318000': [213],
#  'https://www.abcactionnews.com/rebound/coronavirus-money-help/florida-housing-market-takes-major-hit-from-coronavirus-rebound-timeframe-uncertain?fbclid=IwAR0TxNzRSywLpecCZ0houqfAcGwGFE3N6XDmXn7dU8D-ByN6n_zEdh-wkFM': [215],
#  'https://lasillarota.com/estados/nace-otro-bebe-milagro-en-monclova-monclova-bebe-milagro-dia-del-nino-madre-covid/386696': [216],
#  'https://amazon.com/PHANTOM-APOCALYPSE-Dystopian-Jon-Kofas-ebook/dp/B07SLZLC4Q/ref=sr_1_1?keywords=jon+kofas&qid=1563635435&s=gateway&sr=8-1': [217],
#  'https://bit.ly/2y8ciBx': [220],
#  'https://bit.ly/3bUVeO1': [221],
#  'http://www.gob.cl/coronavirus': [222],
#  'http://abcn.ws/2RiH3wd': [223],
#  'http://mill.yt/g3vh4': [225],
#  'https://dailyaaj.com.pk/news/31545': [228],
#  'https://wdrb.news/2KSCnal': [231],
#  'https://www.prosoundnetwork.com/pro-sound-news-blog/pandemic-production-whatever-it-takes': [233],
#  'https://bit.ly/GimnasiosOnline': [235],
#  'https://cbsn.ws/2Wgbvqa': [237],
#  'https://oklahoman.com/article/5661243/coronavirus-stimulus-six-reasons-your-1200-check-may-not-be-in-the-mail': [238],
#  'https://www.gsnoticias.com/recaudo-de-impuestos-en-monteria-ha-caido-en-un-30-por-la-covid-19/': [240],
#  'https://www.comicsands.com/ben-shapiro-elderly-deaths-pandemic-2645883827.html': [241],
#  'https://bit.ly/3ajbWpB': [243],
#  'http://spr.ly/60181fxwi': [246],
#  'https://tkpo.st/2xhyHMe': [247],
#  'https://bit.ly/2YkynHC': [248],
#  'https://247sports.com/college/arkansas/Article/Commissioner-Greg-Sankey-provides-update-on-SEC-Media-Days-July-13-16-Atlanta-COVID-19-coronavirus-pandemic-146634189/': [249],
#  'https://www.instagram.com/p/B_oEJnNnp3L/?igshid=1f0ro9q2skdhi': [252],
#  'https://bit.ly/2YmToBO': [253],
#  'https://jurnaltr.com/elon-musk-koronavirus-onlemlerini-fasistlik-diye-niteledi/': [256],
#  'https://gyao.yahoo.co.jp/special/gw2020/?source=external.twitter': [257],
#  'https://cnycentral.com/news/local/lawyers-anticipate-covid-19-will-change-the-approach-to-living-wills': [259],
#  'http://bit.ly/2z1fqPz': [260],
#  'https://bit.ly/2VT7GIH': [261],
#  'https://www.em.com.br/app/noticia/politica/2020/04/30/interna_politica,1143431/coronavirus-damares-usa-mascara-de-mulher-maravilha-em-apelo-por-cria.shtml': [262],
#  'https://cet.informabi.com/three-more-chick-fil-employees-test-positive-covid-19': [264],
#  'https://i.inewsgr.com/m8ogj': [266],
#  'https://www.aoitori.be/news/belgium/corona-3-may.html': [267],
#  'https://www.aberdeennews.com/ap/national/minnesota-nursing-home-reports-47-deaths-from-coronavirus/article_b4671568-3311-5e79-9bc3-c4bcfd78d109.html?utm_medium=social&utm_source=twitter_AberdeenNews': [273],
#  'https://buff.ly/2y7GcWK': [277],
#  'https://covid19-japan.com/latest': [280],
#  'http://www.tdb.org.tr/icerik_goster.php?Id=3467': [281],
#  'https://www.nytimes.com/2020/04/30/health/coronavirus-antiviral-drugs.html': [282],
#  'https://bit.ly/35mlnTE': [286],
#  'https://www.wlns.com/news/health/coronavirus/sparrow-refocuses-donation-efforts-after-collecting-more-than-270000-items-from-community/?utm_medium=social&utm_source=twitter_WLNS': [289],
#  'https://reut.rs/35iqNir': [295],
#  'https://medium.com/conversations-with-tyler/glen-weyl-tyler-cowen-covid-19-coronavirus-pandemic-relief-e4869e1a7a51': [299]}
